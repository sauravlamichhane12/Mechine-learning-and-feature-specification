# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = np.random.sample(50)

# %%
arr
# Out:
# array([0.59431229, 0.43367089, 0.99909398, 0.05571228, 0.31254325,
#        0.27080289, 0.29594571, 0.46969345, 0.31532108, 0.15865714,
#        0.28029553, 0.08651432, 0.66136201, 0.13503695, 0.56254219,
#        0.81977192, 0.25793487, 0.36641724, 0.12801662, 0.39298484,
#        0.27990306, 0.81239207, 0.31402317, 0.48604528, 0.54774808,
#        0.6573888 , 0.15837395, 0.29237897, 0.64614127, 0.91523656,
#        0.33896289, 0.06917034, 0.16210784, 0.96914655, 0.69425719,
#        0.36432144, 0.27212881, 0.06238493, 0.47620861, 0.71872248,
#        0.86578372, 0.29972744, 0.85842169, 0.27892871, 0.70872865,
#        0.38813063, 0.28863759, 0.51716181, 0.77059952, 0.31672154])

# %%
arr = arr.reshape(5,10)

# %%
arr = arr*100

# %%
arr = arr.astype(np.int32)

# %%
arr
# Out:
# array([[59, 43, 99,  5, 31, 27, 29, 46, 31, 15],
#        [28,  8, 66, 13, 56, 81, 25, 36, 12, 39],
#        [27, 81, 31, 48, 54, 65, 15, 29, 64, 91],
#        [33,  6, 16, 96, 69, 36, 27,  6, 47, 71],
#        [86, 29, 85, 27, 70, 38, 28, 51, 77, 31]], dtype=int32)

# %%
arr[arr>50]
# Out:
# array([59, 99, 66, 56, 81, 81, 54, 65, 64, 91, 96, 69, 71, 86, 85, 70, 51,
#        77], dtype=int32)

# %%
arr[(2,3)]
# Out:
# 48

# %%
y_1 = np.linspace(10,100,15)
y_2 = y_1**2
y_3 = y_1**3

# %%
x = np.linspace(1,15,15)

# %%
plt.plot(x,y_1)
plt.show()

# %%
plt.plot(x,y_2)
plt.show()

# %%
plt.plot(x,y_3)
plt.show()

# %%
plt.plot(x,y_1)
plt.plot(x,y_2)
plt.plot(x,y_3)
plt.show()
