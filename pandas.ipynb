# %%
import numpy as np
import pandas as pd

# %%
dict1={
    'name':['saurav','hgari','satis'],
    'age':[1,4,7],
    'address':['sunwal','butwal','khaireni']
}

# %%
list = [1,2,3]
df = pd.DataFrame(dict1)
df
# Out:
#      name  age   address
# 0  saurav    1    sunwal
# 1   hgari    4    butwal
# 2   satis    7  khaireni

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#      name  age   address
# 0  saurav    1    sunwal
# 1   hgari    4    butwal
# 2   satis    7  khaireni

# %%
df.to_csv('eaxport.csv')

# %%
df.head(3)
# Out:
#      name  age   address
# 0  saurav    1    sunwal
# 1   hgari    4    butwal
# 2   satis    7  khaireni

# %%
df.describe()
# Out:
#        age
# count  3.0
# mean   4.0
# std    3.0
# min    1.0
# 25%    2.5
# 50%    4.0
# 75%    5.5
# max    7.0

# %%
harry = pd.read_csv('Data.csv')

# %%
harry
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0           ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars
# 1           ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars
# 2           ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars
# 3           ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars
# 4           ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 19230       ECTQ.S4AXP  2021.12        33.3        NaN      F  Percent
# 19231       ECTQ.S4AXP  2022.03        33.7        NaN      F  Percent
# 19232       ECTQ.S4AXP  2022.06        33.5        NaN      F  Percent
# 19233       ECTQ.S4AXP  2022.09        33.2        NaN      F  Percent
# 19234       ECTQ.S4AXP  2022.12        32.7        NaN      F  Percent
#
#        Magnitude                                        Subject  \
# ...

# %%
harry['Series_reference'][4]='dfkjjkfd'
# Out:
# /var/folders/61/r_vs5l1j7m91kw2v12g_zjsr0000gn/T/ipykernel_9192/4219283772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   harry['Series_reference'][4]='dfkjjkfd'

# %%
harry['Series_reference'][1]
# Out:
# 'ECTA.S19A1'

# %%
df.index=['first', 'second','third']

# %%
df
# Out:
#           name  age   address
# first   saurav    1    sunwal
# second   hgari    4    butwal
# third    satis    7  khaireni

# %%
ser = pd.Series(np.random.randint(0,6,7))

# %%
ser
# Out:
# 0    1
# 1    2
# 2    0
# 3    2
# 4    4
# 5    1
# 6    4
# dtype: int64

# %%
np.random.randint(8)
# Out:
# 5

# %%
newdf = pd.DataFrame(np.random.rand(35,6))

# %%
newdf
# Out:
#            0         1         2         3         4         5
# 0   0.508933  0.349041  0.730155  0.096438  0.939372  0.664064
# 1   0.606476  0.262465  0.677674  0.878976  0.248201  0.873456
# 2   0.978360  0.698075  0.713358  0.427372  0.035570  0.905797
# 3   0.491030  0.285323  0.624677  0.756481  0.235761  0.347881
newdf[2][3]
# Out:
# 0.6246773878277012

# %%
newdf.loc[0,1]
# Out:
# 0.3490407545446398

# %%
newdf[0][2]
# Out:
# 0.9783597876168951

# %%
newdf.loc[0,1]= 66

# %%
newdf
# Out:
#            0          1         2         3         4         5
# 0     saurav  66.000000  0.730155  0.096438  0.939372  0.664064
# 1   0.606476   0.262465  0.677674  0.878976  0.248201  0.873456
# 2    0.97836   0.698075  0.713358  0.427372  0.035570  0.905797
# 3    0.49103   0.285323  0.624677  0.756481  0.235761  0.347881
# 4    0.16552   0.481862  0.376944  0.056456  0.248232  0.512620
# 5   0.067383   0.220561  0.871953  0.170010  0.597313  0.771866
# 6   0.438137   0.682327  0.183307  0.819882  0.134198  0.349148
# 7   0.118859   0.287730  0.895214  0.035931  0.565015  0.068839
# 8   0.569022   0.732525  0.299837  0.333396  0.939860  0.839993
# 9   0.097105   0.845114  0.817989  0.877031  0.621269  0.116610
# 10  0.127988   0.530361  0.016902  0.342203  0.078022  0.504665
# 11   0.78192   0.131610  0.781579  0.931722  0.059571  0.817839
# 12  0.667727   0.698335  0.357203  0.713297  0.350353  0.912673
# 13    0.9065   0.749929  0.916955  0.042690  0.713631  0.548403
# ...

# %%
list(range(10))

# %%
newdf.columns=list('ABCDEF')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/61/r_vs5l1j7m91kw2v12g_zjsr0000gn/T/ipykernel_9192/3706901051.py in <module>
# ----> 1 newdf.columns=list('ABCDEF')
#
# TypeError: 'list' object is not callable

# %%
newdf.drop(4)
# Out:
#            0          1         2         3         4         5
# 0     saurav  66.000000  0.730155  0.096438  0.939372  0.664064
# 1   0.606476   0.262465  0.677674  0.878976  0.248201  0.873456
# 2    0.97836   0.698075  0.713358  0.427372  0.035570  0.905797
# 3    0.49103   0.285323  0.624677  0.756481  0.235761  0.347881
# 5   0.067383   0.220561  0.871953  0.170010  0.597313  0.771866
# 6   0.438137   0.682327  0.183307  0.819882  0.134198  0.349148
# 7   0.118859   0.287730  0.895214  0.035931  0.565015  0.068839
# 8   0.569022   0.732525  0.299837  0.333396  0.939860  0.839993
# 9   0.097105   0.845114  0.817989  0.877031  0.621269  0.116610
# 10  0.127988   0.530361  0.016902  0.342203  0.078022  0.504665
# 11   0.78192   0.131610  0.781579  0.931722  0.059571  0.817839
# 12  0.667727   0.698335  0.357203  0.713297  0.350353  0.912673
# 13    0.9065   0.749929  0.916955  0.042690  0.713631  0.548403
# 14  0.229632   0.363976  0.251000  0.891703  0.897197  0.685023
# ...

# %%
newdf['A'][1]=567
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/61/r_vs5l1j7m91kw2v12g_zjsr0000gn/T/ipykernel_9192/2987534736.py in <module>
# ----> 1 newdf['A'][1]=567
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     386                 except ValueError as err:
#     387                     raise KeyError(key) from err
# --> 388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#     390
#
# ...

# %%
newdf.iloc[2,0]
# Out:
# 0.9783597876168951

# %%
newdf.loc[3, :]= 456 #to chnge the row value
newdf.loc[:,1] = 546 #to change the whole column value

# %%
newdf
# Out:
#       0    1           2           3           4           5
# 0   456  546    0.730155    0.096438    0.939372    0.664064
# 1   456  546    0.677674    0.878976    0.248201    0.873456
# 2   456  546    0.713358    0.427372    0.035570    0.905797
# 3   456  546  456.000000  456.000000  456.000000  456.000000
# 4   456  546    0.376944    0.056456    0.248232    0.512620
# 5   456  546    0.871953    0.170010    0.597313    0.771866
# 6   456  546    0.183307    0.819882    0.134198    0.349148
# 7   456  546    0.895214    0.035931    0.565015    0.068839
# 8   456  546    0.299837    0.333396    0.939860    0.839993
# 9   456  546    0.817989    0.877031    0.621269    0.116610
# 10  456  546    0.016902    0.342203    0.078022    0.504665
# 11  456  546    0.781579    0.931722    0.059571    0.817839
# 12  456  546    0.357203    0.713297    0.350353    0.912673
# 13  456  546    0.916955    0.042690    0.713631    0.548403
# ...

# %%
newdf.info()

# %%
newdf[4:8]

# %%
newdf.columns

# %%
newdf =newdf.drop('A', axis=1) #to drop the column (above we have the A column in the df dataset so we allocated the string for 'A' and for integer we represent only the number)
newdf= newdf.drop(2, axis=0)  #to drop the row

# %%
newdf

# %%
newdf[[0,1,3]]

# %%
df = pd.DataFrame(np.random.rand(3,4))

# %%
newdf = df.copy()

# %%
newdf[0][1]=555

# %%
newdf

# %%
df

# %%
pd.read_csv('Data.csv')

# %%
weather_data = [('32/4/2022', 32,4,'sunny'),('32/4/2022', 32,4,'sunny')] #tuples list
weather_data = [{'32/4/2022', 32,4,'sunny'},{'32/4/2022', 32,4,'sunny'}] #dictionary list
weather_data = [['32/4/2022', 32,4,'sunny'],['32/4/2022', 32,4,'sunny']] #2d list
list=[[2,4], [5,6]]
print(weather_data)

# %%
weather_data1 ={
    'days':['32/4/2012','23/4/2022', '4/5/6'],
    'temperatiure':[34,36,57],
    'wind':[3,46,78],
    'weather':['Sunny','hot','cold']
}
pd.DataFrame(weather_data1)

# %%
pd.DataFrame(weather_data, columns=['days', 'temperature', 'wind', 'weather'])

# %%
pd.DataFrame(list)

# %%
weather_data1 ={
    'days':['32/4/2012','23/4/2022', '4/5/6'],
    'temperatiure':[34,36,57],
    'wind':[3,46,78],
    'weather':['Sunny','hot','cold']
}

# %%
pd.DataFrame(weather_data1)

# %%
newdf = df.replace('Sunny', np.NaN)

# %%
newdf
